# %% [markdown]
# # Combining and Exporting Data 2

# %% [markdown]
# ## Objective of Script

# %%
# 1. Import the data set into Jupyter as a new dataframe: df_ords_prior.
# 2. Check the dimensions of the imported dataframe.
# 3. Merge the dataframe with your df_ords dataframe.
# 4. Use the indicator argument to check whether there was a full match between the two dataframes.

# %% [markdown]
# ## 01. Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Import Dataframes

# %%
# Import dataframe, creating shortcut to data file

path = r'/Users/tatumzeliadt/Library/CloudStorage/OneDrive-Personal/Data Analytics/Data Immersion/4 Achievement 4 Python Fundamentals for Data Analysts/Instacart Basket Analysis'

# %%
# Verify path

path
# Out:
# '/Users/tatumzeliadt/Library/CloudStorage/OneDrive-Personal/Data Analytics/Data Immersion/4 Achievement 4 Python Fundamentals for Data Analysts/Instacart Basket Analysis'

# %%
# Import dataframe orders_products_combined using path shortcut from Prepared Data folder

df_orders_products_combined = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Import dataframe products_checked using path shortcut from Prepared Data folder

df_prods = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %% [markdown]
# ## 03. Dimensions Check

# %%
# Dimension check of orders_products_combined dataset

df_orders_products_combined.shape
# Out:
# (32434489, 10)

# %%
# Dimension check of products_checked

df_prods.shape
# Out:
# (49672, 6)

# %%
# Check first five rows of orders_products_combined dataset

df_orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
# Check last five rows of orders_products_combined dataset

df_orders_products_combined.tail()
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 32434484   2977660   206209            13                   1
# 32434485   2977660   206209            13                   1
# 32434486   2977660   206209            13                   1
# 32434487   2977660   206209            13                   1
# 32434488   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 32434484                 12                     7.0       14197
# 32434485                 12                     7.0       38730
# 32434486                 12                     7.0       31477
# 32434487                 12                     7.0        6567
# 32434488                 12                     7.0       22920
#
#           add_to_cart_order  reordered _merge
# 32434484                  5          1   both
# 32434485                  6          0   both
# 32434486                  7          0   both
# ...

# %%
# Dataframe information of orders_products_combined dataset

df_orders_products_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32434489 entries, 0 to 32434488
# Data columns (total 10 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   product_id              int64
#  7   add_to_cart_order       int64
#  8   reordered               int64
#  9   _merge                  category
# dtypes: category(1), float64(1), int64(8)
# memory usage: 2.4 GB

# %%
# Dropping _merge column as need to rerun once merged with another dataframe

df_orders_products_combined = df_orders_products_combined.drop(columns = ['_merge'])

# %%
# Descriptive statistics of orders_products_combined dataset

df_orders_products_combined.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.243449e+07  3.243449e+07  3.243449e+07        3.243449e+07
# mean   1.710749e+06  1.029372e+05  1.714205e+01        2.738818e+00
# std    9.873007e+05  5.946648e+04  1.753504e+01        2.090049e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559430e+05  5.142100e+04  5.000000e+00        1.000000e+00
# 50%    1.711048e+06  1.026110e+05  1.100000e+01        3.000000e+00
# 75%    2.565514e+06  1.543910e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.243449e+07            3.035642e+07  3.243449e+07
# mean        1.342498e+01            1.110407e+01  2.557634e+04
# std         4.246365e+00            8.778914e+00  1.409669e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# ...

# %%
# Check first five rows of products_checked dataset

df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Check last five rows of products_checked dataset

df_prods.tail()
# Out:
#        Unnamed: 0  product_id                                product_name  \
# 49667       49688       49684   Vodka, Triple Distilled, Twist of Vanilla
# 49668       49689       49685          En Croute Roast Hazelnut Cranberry
# 49669       49690       49686                            Artisan Baguette
# 49670       49691       49687  Smartblend Healthy Metabolism Dry Cat Food
# 49671       49692       49688                      Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 49667       124              5     5.3
# 49668        42              1     3.1
# 49669       112              3     7.8
# 49670        41              8     4.7
# 49671        73             11    13.5

# %%
# Dataframe information of products_checked dataset

df_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49672 entries, 0 to 49671
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     49672 non-null  int64
#  1   product_id     49672 non-null  int64
#  2   product_name   49672 non-null  object
#  3   aisle_id       49672 non-null  int64
#  4   department_id  49672 non-null  int64
#  5   prices         49672 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.3+ MB

# %%
# Descriptive statistics of products_checked dataset

df_prods.describe()
# Out:
#          Unnamed: 0    product_id      aisle_id  department_id        prices
# count  49672.000000  49672.000000  49672.000000   49672.000000  49672.000000
# mean   24852.005053  24850.349775     67.762442      11.728942      9.993282
# std    14342.265579  14340.705287     38.315784       5.850779    453.615536
# min        0.000000      1.000000      1.000000       1.000000      1.000000
# 25%    12432.750000  12432.750000     35.000000       7.000000      4.100000
# 50%    24851.500000  24850.500000     69.000000      13.000000      7.100000
# 75%    37272.250000  37268.250000    100.000000      17.000000     11.100000
# max    49692.000000  49688.000000    134.000000      21.000000  99999.000000

# %%
# Dropping Unnamed:01 column as it does not have meaning 

df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
# Recheck of the first five rows of products_checked dataset

df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# ## 04. Merge two dataframes (orders_products_combined and products_checked via product_id column)

# %%
# Merging using the product_id column; full merge

df_orders_products_merged = df_orders_products_combined.merge(df_prods, on = 'product_id', indicator = True)

# %% [markdown]
# ## 05. Post Merge Dimension Check

# %%
# View new merged dataframe, first five rows

df_orders_products_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %%
# View new merged dataframe, first five rows

df_orders_products_merged.head()
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 32404854   1320836   202557            17                   2
# 32404855     31526   202557            18                   5
# 32404856    758936   203436             1                   2
# 32404857   2745165   203436             2                   3
# 32404858   3093936   205420             1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 32404854                 15                     1.0       43553
# 32404855                 11                     3.0       43553
# 32404856                  7                     NaN       42338
# 32404857                  5                    15.0       42338
# 32404858                 14                     NaN       28818
#
#           add_to_cart_order  reordered                   product_name  \
# 32404854                  2          1            Orange Energy Shots
# ...

# %%
# Check value counts for '_merge' column

df_orders_products_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# View new merged dataframe information 

df_orders_products_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 14 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   product_id              int64
#  7   add_to_cart_order       int64
#  8   reordered               int64
#  9   product_name            object
#  10  aisle_id                int64
#  11  department_id           int64
#  12  prices                  float64
#  13  _merge                  category
# dtypes: category(1), float64(2), int64(10), object(1)
# memory usage: 3.4+ GB

# %%
# Dimension check of new merged dataframe

df_orders_products_merged.shape
# Out:
# (32404859, 14)

# %% [markdown]
# ## 06. Exporting Data

# %%
# Exporting merged dataframes df_orders_products_merged as orders_products_merged

df_orders_products_merged.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_merged.pkl'))
