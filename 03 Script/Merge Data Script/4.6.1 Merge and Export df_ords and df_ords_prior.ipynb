# %% [markdown]
# # Combining and Exporting Data

# %% [markdown]
# ## Objective of script

# %%
# 1. Import the data set into Jupyter as a new dataframe: df_ords_prior.
# 2. Check the dimensions of the imported dataframe.
# 3. Merge the dataframe with your df_ords dataframe.
# 4. Use the indicator argument to check whether there was a full match between the two dataframes.

# %% [markdown]
# ## 01. Import Libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Import dataframes

# %%
# Import dataframe, creating shortcut to data file

path = r'/Users/tatumzeliadt/Library/CloudStorage/OneDrive-Personal/Data Analytics/Data Immersion/4 Achievement 4 Python Fundamentals for Data Analysts/Instacart Basket Analysis'

# %%
# Verify path

path
# Out:
# '/Users/tatumzeliadt/Library/CloudStorage/OneDrive-Personal/Data Analytics/Data Immersion/4 Achievement 4 Python Fundamentals for Data Analysts/Instacart Basket Analysis'

# %%
# Import dataframe order_products_prior as df_ords_prior using path shortcut from Original Data folder

df_ords_prior = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'order_products_prior.csv'), index_col = False)

# %%
# Import dataframe ord as df_ords using path shortcut from Prepared Data folder

df_ords = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'orders_checked.csv'), index_col =False)

# %% [markdown]
# ## 03. Dimensions Check

# %%
# Dimension Check of df_ords_prior dataset

df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
# Check first five rows

df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Check last five rows

df_ords_prior.tail()
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1

# %%
# Dataframe information

df_ords_prior.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB

# %%
# Descriptive statistics 

df_ords_prior.describe()
# Out:
#            order_id    product_id  add_to_cart_order     reordered
# count  3.243449e+07  3.243449e+07       3.243449e+07  3.243449e+07
# mean   1.710749e+06  2.557634e+04       8.351076e+00  5.896975e-01
# std    9.873007e+05  1.409669e+04       7.126671e+00  4.918886e-01
# min    2.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.559430e+05  1.353000e+04       3.000000e+00  0.000000e+00
# 50%    1.711048e+06  2.525600e+04       6.000000e+00  1.000000e+00
# 75%    2.565514e+06  3.793500e+04       1.100000e+01  1.000000e+00
# max    3.421083e+06  4.968800e+04       1.450000e+02  1.000000e+00

# %%
# Dimension Check of df_ords dataset

df_ords.shape
# Out:
# (3421083, 8)

# %%
# Check first five rows

df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           1   2398795        1    prior             2                   3
# 2           2    473747        1    prior             3                   3
# 3           3   2254736        1    prior             4                   4
# 4           4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
# Check last five rows

df_ords.tail()
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 3421078     3421078   2266710   206209    prior            10
# 3421079     3421079   1854736   206209    prior            11
# 3421080     3421080    626363   206209    prior            12
# 3421081     3421081   2977660   206209    prior            13
# 3421082     3421082    272231   206209    train            14
#
#          orders_day_of_week  order_hour_of_day  days_since_prior_order
# 3421078                   5                 18                    29.0
# 3421079                   4                 10                    30.0
# 3421080                   1                 12                    18.0
# 3421081                   1                 12                     7.0
# 3421082                   6                 14                    30.0

# %%
# Dropping eval_set column 

df_ords = df_ords.drop(columns = ['eval_set'])

# %%
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
# Dropping Unnamed:01 column as it is a duplicate to index 

df_ords = df_ords.drop(columns = ['Unnamed: 0'])

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Dataframe information

df_ords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 6 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
# dtypes: float64(1), int64(5)
# memory usage: 156.6 MB

# %%
# Descriptive statistics 

df_ords.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# ...

# %% [markdown]
# ## 04. Merge two dataframes ( df_ords with df_ords_prior)

# %%
# Merging using the order_id column 

df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
# View new merged dataframe, first five rows

df_merged_large.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
# Check Full merge count

df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Dimension Check of merged dataset

df_merged_large.shape
# Out:
# (32434489, 10)

# %% [markdown]
# ## 05. Post Merge Dimension Check

# %%
# Check first five rows

df_merged_large.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
# Check last five rows

df_merged_large.tail()
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 32434484   2977660   206209            13                   1
# 32434485   2977660   206209            13                   1
# 32434486   2977660   206209            13                   1
# 32434487   2977660   206209            13                   1
# 32434488   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 32434484                 12                     7.0       14197
# 32434485                 12                     7.0       38730
# 32434486                 12                     7.0       31477
# 32434487                 12                     7.0        6567
# 32434488                 12                     7.0       22920
#
#           add_to_cart_order  reordered _merge
# 32434484                  5          1   both
# 32434485                  6          0   both
# 32434486                  7          0   both
# ...

# %%
# Dataframe information

df_merged_large.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32434489 entries, 0 to 32434488
# Data columns (total 10 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   product_id              int64
#  7   add_to_cart_order       int64
#  8   reordered               int64
#  9   _merge                  category
# dtypes: category(1), float64(1), int64(8)
# memory usage: 2.4 GB

# %% [markdown]
# ## 06. Exporting Data

# %%
# Exporting merged data as pickel format

df_merged_large.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_combined.pkl'))
